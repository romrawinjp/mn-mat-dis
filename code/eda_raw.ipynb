# %%
# library is in basee
import os
import igl
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt

from meshplot import plot, subplot, interact

# %%
pwd
# Out:
# 'd:\\my_website\\mn-mat-dis\\code'

# %%
root_dir = os.getcwd()
print(root_dir)

sample_dir = "../raw_sample/tapered-cone-solid/RUBBER-9000-P1V5000"
folder_list = [i for i in os.listdir(sample_dir) if ".csv" in i]
print(folder_list)

feature = pd.read_csv(os.path.join(sample_dir, folder_list[0])).iloc[:, 1:]
print("Shape of feature: ", feature.shape)
print(feature.head())

xs = feature["x"]
ys = feature["y"]
zs = feature["z"]
# Out:
# d:\my_website\mn-mat-dis\code
# ['Elastic Strain Intensity.csv', 'Equivalent Elastic Strain.csv', 'Equivalent Stress.csv', 'LOCX.csv', 'LOCY.csv', 'LOCZ.csv', 'LOC_DEFX.csv', 'LOC_DEFY.csv', 'LOC_DEFZ.csv', 'Stress Intensity.csv', 'Total Acceleration.csv', 'Total Deformation.csv', 'Total Velocity.csv', 'USUM.csv', 'UVECTORS.csv', 'UX.csv', 'UY.csv', 'UZ.csv']
# Shape of feature:  (24667, 25)
#     node        x     y             z   t1   t2        t3        t4        t5  \
# 0  12644 -0.24189  0.31 -1.788100e-08  0.0  0.0  0.000014  0.000329  0.001084
# 1  12645 -0.24037  0.31 -2.750200e-02  0.0  0.0  0.000014  0.000282  0.000559
# 2  12646 -0.23584  0.31 -5.467000e-02  0.0  0.0  0.000012  0.000397  0.000789
# 3  12647 -0.22835  0.31 -8.117500e-02  0.0  0.0  0.000012  0.000143  0.000735
# 4  12648 -0.21798  0.31 -1.066900e-01  0.0  0.0  0.000009  0.000087  0.000348
#
#          t6  ...       t12      t13      t14      t15       t16      t17  \
# ...

# %%
location = ["LOCX.csv", "LOCY.csv", "LOCZ.csv"]
locx = pd.read_csv(os.path.join(sample_dir, location[0]))
locy = pd.read_csv(os.path.join(sample_dir, location[1]))
locz = pd.read_csv(os.path.join(sample_dir, location[2]))

# %%
locx
# Out:
#        Unnamed: 0   node        x        y             z       t1       t2  \
# 0               0  12644 -0.24189  0.31000 -1.788100e-08 -0.24189 -0.24189
# 1               1  12645 -0.24037  0.31000 -2.750200e-02 -0.24037 -0.24037
# 2               2  12646 -0.23584  0.31000 -5.467000e-02 -0.23584 -0.23584
# 3               3  12647 -0.22835  0.31000 -8.117500e-02 -0.22835 -0.22835
# 4               4  12648 -0.21798  0.31000 -1.066900e-01 -0.21798 -0.21798
# ...           ...    ...      ...      ...           ...      ...      ...
# 24662       24662  10267  0.86376 -0.53243  8.756400e-01  0.86376  0.86376
# 24663       24663  10268  0.77630 -0.33627 -5.211100e-01  0.77630  0.77630
# 24664       24664  10269 -0.33101 -0.44993 -3.816600e-01 -0.33101 -0.33101
# 24665       24665  10270  0.56365 -0.84167  2.590200e-01  0.56365  0.56365
# 24666       24666  10271  0.46474 -0.43606 -6.520800e-01  0.46474  0.46474
#
# ...
